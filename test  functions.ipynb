# %%
# !python functions.py
## note after making changes,kernel must be restarted for changes to apply

# %%
import functions
import datasets

DS = datasets.Datasets()

# %%
tweets = DS.tweets_df
retweets = DS.retweets_df
twitter = tweets.append(retweets)
data_name = "twitter"## to be changed

# %%
data = twitter 
data = functions.balance_data(data)
# Out:
# HC length:  1522
# DT length:  3038
# missing_rows: 1516 row_fraction: 0.9960578186596584
# DT length ratio:  0.5

# %%
## maybe this should be made into a function?
from sklearn.model_selection import train_test_split
X = twitter.loc[:,'Loaded_Language':'Thought-terminating_Cliches',]
Y = twitter.loc[:,"BCandidate"]

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = .2,shuffle=True)

# %%
## config stuff 
name = 'extra trees'
model, param_grid = functions.choose_model(name)

# %%
trained_model = functions.model_training(model,X_train, Y_train, param_grid)

# %%
filename = functions.save_model(trained_model,name,data_name)

# %%
loaded_model = functions.scorer(filename, X_test, Y_test)
# Out:
# extra trees_GS_twitter results on test data
# roc_auc: 0.5946415175222377
# accurarcy: 0.6951754385964912
# note 1 is Donald Trump

# %%
functions.graph_MDI_importance(X_train,Y_train,loaded_model,name)

# %%
functions.show_permutation_feature_importance(loaded_model, X_train, Y_train, name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10900/3692733841.py in <module>
# ----> 1 functions.show_permutation_feature_importance(loaded_model, X_train, Y_train, name)
#
# ~\propaganda classification\functions.py in show_permutation_feature_importance(loaded_model, X_train, Y_train, name)
#     220     scoring = ['roc_auc', 'accuracy']#
#     221     r_multi = permutation_importance(
# --> 222         MOD, X_test, Y_test, n_repeats=30, random_state=0, scoring=scoring)## n_repeats should be bigger
#     223
#     224     features= list(twitter.columns)[6:-2]
#
# NameError: name 'X_test' is not defined
