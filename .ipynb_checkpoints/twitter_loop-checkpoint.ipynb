# %%
# !python functions.py
## note after making changes,kernel must be restarted for changes to apply

# %%
import functions
import datasets
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\theot\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
DS = datasets.Datasets()
tweets = DS.tweets_df
tweets
# Out:
#             File Name  BCandidate Content_Category  Appeal_to_Authority  \
# 0         DT0_500.txt           1            tweet                  1.0
# 1     DT1000_1500.txt           1            tweet                  3.0
# 2     DT1500_2000.txt           1            tweet                  1.0
# 3     DT2000_2500.txt           1            tweet                  0.0
# 4     DT2500_3000.txt           1            tweet                  5.0
# ...               ...         ...              ...                  ...
# 1240  HC1500_2000.txt           0            tweet                 11.0
# 1241  HC2000_2500.txt           0            tweet                  5.0
# 1242  HC2500_3000.txt           0            tweet                  0.0
# 1243  HC3000_3500.txt           0            tweet                  4.0
# 1244   HC500_1000.txt           0            tweet                  3.0
#
#       Appeal_to_fear-prejudice  Bandwagon,Reductio_ad_hitlerum  \
# 0                          3.0                             0.0
# 1                          6.0                             0.0
# 2                          5.0                             0.0
# 3                          2.0                             0.0
# 4                          1.0                             2.0
# ...                        ...                             ...
# 1240                      21.0                             1.0
# 1241                      13.0                             3.0
# 1242                      22.0                             0.0
# 1243                      11.0                             0.0
# 1244                      15.0                             0.0
#
#       Black-and-White_Fallacy  Causal_Oversimplification  Doubt  \
# 0                         5.0                        5.0   28.0
# 1                         3.0                        4.0   46.0
# 2                         4.0                        6.0   31.0
# 3                         7.0                        4.0   26.0
# 4                         6.0                        5.0   32.0
# ...                       ...                        ...    ...
# 1240                     11.0                        4.0   14.0
# 1241                      7.0                        4.0   15.0
# 1242                     14.0                        6.0   24.0
# 1243                      8.0                        1.0    3.0
# 1244                     10.0                       12.0   26.0
#
#       Exaggeration,Minimisation  Flag-Waving  Loaded_Language  \
# 0                          12.0         20.0             65.0
# 1                          31.0         12.0             79.0
# 2                          19.0         11.0             72.0
# 3                          19.0         14.0             96.0
# 4                          21.0         19.0             75.0
# ...                         ...          ...              ...
# 1240                       42.0         44.0             43.0
# 1241                       22.0         46.0             54.0
# 1242                       16.0         48.0             50.0
# 1243                        9.0          5.0             22.0
# 1244                       30.0         36.0             52.0
#
#       Name_Calling,Labeling  Num Prop  \
# 0                      49.0     410.0
# 1                      41.0     474.0
# 2                      31.0     425.0
# 3                      52.0     474.0
# 4                      45.0     407.0
# ...                     ...       ...
# 1240                   31.0     323.0
# 1241                   31.0     293.0
# 1242                   14.0     283.0
# 1243                    5.0     117.0
# 1244                   32.0     290.0
#
#       Obfuscation,Intentional_Vagueness,Confusion  Repetition  Slogans  \
# 0                                             0.0        82.0     30.0
# 1                                             0.0        79.0     25.0
# 2                                             0.0        99.0     31.0
# 3                                             0.0        88.0     35.0
# 4                                             0.0        72.0     21.0
# ...                                           ...         ...      ...
# 1240                                          0.0        16.0     26.0
# 1241                                          0.0         6.0     26.0
# 1242                                          0.0        10.0     19.0
# 1243                                          0.0         2.0     17.0
# 1244                                          0.0         3.0     13.0
#
#       Thought-terminating Cliches  Thought-terminating_Cliches  \
# 0                             0.0                         10.0
# 1                             0.0                         11.0
# 2                             0.0                         16.0
# 3                             0.0                          8.0
# 4                             0.0                         13.0
# ...                           ...                          ...
# 1240                          0.0                          9.0
# 1241                          0.0                         10.0
# 1242                          0.0                         12.0
# 1243                          0.0                          7.0
# 1244                          0.0                          9.0
#
#       Whataboutism,Straw_Men,Red_Herring
# 0                                    4.0
# 1                                    3.0
# 2                                    3.0
# 3                                    5.0
# 4                                    2.0
# ...                                  ...
# 1240                                 5.0
# 1241                                 6.0
# 1242                                10.0
# 1243                                 5.0
# 1244                                 7.0
#
# [945 rows x 20 columns]

# %%
def twitter_loop():
    DS = datasets.Datasets()
    tweets = DS.tweets_df
    retweets = DS.retweets_df
    twitter = tweets.append(retweets)
    data_name = "twitter"## to be changed
    
    data = twitter 
    print(data["BCandidate"])
    data = functions.balance_data(data)
    
    X = data.loc[:,'Loaded_Language':'Thought-terminating_Cliches',]
    Y = data.loc[:,"BCandidate"]

    X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = .2,shuffle=True)
   
    RF_ET_name = ['extra trees', 'random forest']
    for name in RF_ET_name:
        model, param_grid = functions.choose_model(name)
        trained_model = functions.model_training(model,X_train, Y_train, param_grid)
        filename = functions.save_model(trained_model,name,data_name)
        loaded_model = functions.scorer(filename, X_test, Y_test)
        functions.graph_MDI_importance(X_train,Y_train,loaded_model,name, data_name)
        functions.show_permutation_feature_importance(loaded_model, X_train, Y_train, name, data_name)
        print(name + ': Done!')

    
    SVM_LO_NN = ["support vector machine",'neural net']#'lasso', ## this cannot be used because it cannon predict by classification
    for name in SVM_LO_NN :
        model, param_grid = functions.choose_model(name)
        trained_model = functions.model_training(model,X_train, Y_train, param_grid)
        filename = functions.save_model(trained_model,name,data_name)
        loaded_model = functions.scorer(filename, X_test, Y_test)
        print(name + ': Done!')
    
    #functions.barchart(data, data_name)
    #functions.boxplotting(data)
    
        
twitter_loop()
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 291    1
# 292    1
# 293    1
# 294    1
# 295    1
# Name: BCandidate, Length: 1069, dtype: int64
# HC length:  0
# DT length:  0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-ced13c47f1d6> in <module>
#      38
#      39
# ---> 40 twitter_loop()
#
# <ipython-input-6-ced13c47f1d6> in twitter_loop()
#       8     data = twitter
#       9     print(data["BCandidate"])
# ---> 10     data = functions.balance_data(data)
#      11
#      12     X = data.loc[:,'Loaded_Language':'Thought-terminating_Cliches',]
#
# ~\propaganda-classification\functions.py in balance_data(data)
#      67         print('look at function "balance_data"')
#      68     missing_rows = A-B
# ---> 69     row_fraction = missing_rows/B
#      70     print('missing_rows:', missing_rows, 'row_fraction:', row_fraction)
#      71     for i in range(0,math.floor(row_fraction),1):
#
# ZeroDivisionError: division by zero

# %%
#functions.barchart(data, data_name)

# %%
#boxplotting(data)
