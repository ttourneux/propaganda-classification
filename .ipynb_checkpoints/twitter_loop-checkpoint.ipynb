# %%
# !python functions.py
## note after making changes,kernel must be restarted for changes to apply

# %%
import functions
import datasets
from sklearn.model_selection import train_test_split

# %%
def twitter_loop():
    DS = datasets.Datasets()
    tweets = DS.tweets_df
    retweets = DS.retweets_df
    twitter = tweets.append(retweets)
    data_name = "twitter"## to be changed
    
    data = twitter 
    data = functions.balance_data(data)
    
    X = twitter.loc[:,'Loaded_Language':'Thought-terminating_Cliches',]
    Y = twitter.loc[:,"BCandidate"]

    X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = .2,shuffle=True)
    
    RF_ET_name = ['extra trees', 'random forest']
    for name in RF_ET_name:
        model, param_grid = functions.choose_model(name)
        trained_model = functions.model_training(model,X_train, Y_train, param_grid)
        filename = functions.save_model(trained_model,name,data_name)
        loaded_model = functions.scorer(filename, X_test, Y_test)
        functions.graph_MDI_importance(X_train,Y_train,loaded_model,name, data_name)
        functions.show_permutation_feature_importance(loaded_model, X_train, Y_train, name, data_name)
        print(name + ': Done!')
    
    SVM_LO_NN = ["support vector machine",'lasso','neural net']
    for name in SVM_LO_NN :
        model, param_grid = functions.choose_model(name)
        trained_model = functions.model_training(model,X_train, Y_train, param_grid)
        filename = functions.save_model(trained_model,name,data_name)
        loaded_model = functions.scorer(filename, X_test, Y_test)
        print(name + ': Done!')
        
    functions.barchart(data, data_name)
    functions.boxplotting(data)
    
        
twitter_loop()
# Out:
# HC length:  1522
# DT length:  3038
# missing_rows: 1516 row_fraction: 0.9960578186596584
# DT length ratio:  0.5
# extra trees_GS_twitter results on test data
# roc_auc: 0.6392448610991657
# accurarcy: 0.7171052631578947
# note 1 is Donald Trump
# extra trees: Done!
# random forest_GS_twitter results on test data
# roc_auc: 0.6408359852068461
# accurarcy: 0.7171052631578947
# note 1 is Donald Trump
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7172/1157614428.py in <module>
#      32         print(name + ': Done!')
#      33
# ---> 34 twitter_loop()
#
# ~\AppData\Local\Temp/ipykernel_7172/1157614428.py in twitter_loop()
#      19         trained_model = functions.model_training(model,X_train, Y_train, param_grid)
#      20         filename = functions.save_model(trained_model,name,data_name)
# ---> 21         loaded_model = functions.scorer(filename, X_test, Y_test)
#      22         functions.graph_MDI_importance(X_train,Y_train,loaded_model,name, data_name)
#      23         functions.show_permutation_feature_importance(loaded_model, X_train, Y_train, name, data_name)
#
# ~\propaganda classification\functions.py in scorer(filename, X_test, Y_test)
#     152     ConfusionMatrixDisplay(cm).plot()
#     153
# --> 154     json_ptr = open("scores/scores.json")
#     155     scores = json.load(json_ptr)
#     156     scores["roc_auc"] = roc_auc_score(Y_test,loaded_model.predict(X_test))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scores.json'

# %%
functions.barchart(data, data_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7172/2518062614.py in <module>
# ----> 1 functions.barchart(data, data_name)
#
# NameError: name 'data' is not defined

# %%
boxplotting(data)
